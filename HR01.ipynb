# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../DataSets/HR_Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df.BusinessTravel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sb.histplot(x=df.Age)
plt.show()

# %%
sb.histplot(x=df.MonthlyIncome)
plt.show()

# %%
sb.barplot(x=df.Attrition,y=df.MonthlyIncome)
plt.show()

# %%
sb.barplot(x=df.Attrition,y=df.JobSatisfaction)
plt.show()

# %%
sb.barplot(x=df.Attrition,y=df.RelationshipSatisfaction,palette='spring')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15548\119155003.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Attrition,y=df.RelationshipSatisfaction,palette='spring')

# %%
sb.barplot(x=df.JobRole,y=df.MonthlyIncome,palette='spring')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15548\4189771203.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.JobRole,y=df.MonthlyIncome,palette='spring')

# %%
correlation_matrix=df.corr(numeric_only=True)
correlation_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(16,12))
sb.heatmap(correlation_matrix,annot=True,cmap='Set2',fmt=".2f",cbar=True)
plt.title('Correlation Matrix')
plt.show()

# %%
df[(df.Attrition=='Yes')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df[(df.Attrition=='No')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,3,1)
sb.boxplot(x=df.Attrition,y=df.JobSatisfaction)

plt.subplot(1,3,2)
sb.boxplot(x=df.Attrition,y=df.MonthlyIncome)

plt.subplot(1,3,3)
sb.boxplot(x=df.Attrition,y=df.PerformanceRating)
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,4,1)
sb.countplot(data=df,x='Age',hue='Attrition')


plt.subplot(1,4,2)
sb.countplot(data=df,x='Department',hue='Attrition')
plt.xticks(rotation=90)

plt.subplot(1,4,3)
sb.countplot(data=df,x='EducationField',hue='Attrition')
plt.xticks(rotation=90)


plt.subplot(1,4,4)
sb.histplot(data=df,x='Age',hue='Attrition',multiple="stack")
plt.show()

# %%
D=df.Department.value_counts()
D
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
plt.pie(D.values,labels=D.index,autopct='%d%%')
plt.show()

# %%
A=df.Attrition.value_counts()
A
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
plt.pie(A.values,labels=A.index,autopct='%d%%')
plt.show()

# %%
G=df.Gender.value_counts()
G
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
plt.pie(A.values,labels=A.index,autopct='%d%%')
plt.show()

# %%
sb.barplot(x=df.Attrition,y=df.MonthlyIncome)
plt.show()

# %%
sb.barplot(x=df.Attrition,y=df.MonthlyIncome)
plt.show()

# %%
pd.crosstab(index=df.Attrition,columns=df.Department,margins=True)
# Out:
# Department  Human Resources  Research & Development  Sales   All
# Attrition
# No                       51                     828    354  1233
# Yes                      12                     133     92   237
# All                      63                     961    446  1470

# %%
pd.crosstab(index=df.Attrition,columns=df.JobSatisfaction,margins=True)
# Out:
# JobSatisfaction    1    2    3    4   All
# Attrition
# No               223  234  369  407  1233
# Yes               66   46   73   52   237
# All              289  280  442  459  1470

# %%
pd.crosstab(index=df.Attrition,columns=df.Gender,margins=True)
# Out:
# Gender     Female  Male   All
# Attrition
# No            501   732  1233
# Yes            87   150   237
# All           588   882  1470

# %%
pd.crosstab(index=df.Attrition,columns=df.JobRole,margins=True)
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# No                               122               40                    197
# Yes                                9               12                     62
# All                              131               52                    259
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# No              97                     135                 78
# Yes              5                      10                  2
# All            102                     145                 80
#
# JobRole    Research Scientist  Sales Executive  Sales Representative   All
# Attrition
# No                        245              269                    50  1233
# Yes                        47               57                    33   237
# All                       292              326                    83  1470

# %%
df.groupby('JobSatisfaction')['EmployeeNumber'].max().reset_index()
# Out:
#    JobSatisfaction  EmployeeNumber
# 0                1            2062
# 1                2            2065
# 2                3            2068
# 3                4            2061

# %%
df.groupby('Department')['PerformanceRating'].mean().nlargest(5)
# Out:
# Department
# Research & Development    3.162331
# Human Resources           3.142857
# Sales                     3.136771
# Name: PerformanceRating, dtype: float64

# %%
df.groupby(['Department','EmployeeNumber'])['YearsAtCompany'].max().reset_index()
# Out:
#            Department  EmployeeNumber  YearsAtCompany
# 0     Human Resources             103               4
# 1     Human Resources             133               3
# 2     Human Resources             140               3
# 3     Human Resources             148               5
# 4     Human Resources             177               8
# ...               ...             ...             ...
# 1465            Sales            2046               5
# 1466            Sales            2055               3
# 1467            Sales            2056              20
# 1468            Sales            2060               4
# 1469            Sales            2065               9
#
# [1470 rows x 3 columns]

# %%
E=df.EducationField.value_counts()
E
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
plt.pie(E.values,labels=E.index,autopct='%d%%')
plt.show()
